# %%
import pandas as pd

df = pd.read_csv('aqidataset.csv')

# %%
df
# Out:
#        Unnamed: 0        Date  Overall AQI Value Main Pollutant  \
# 0               0  01/01/2023                 28          Ozone
# 1               1  01/02/2023                 26          Ozone
# 2               2  01/03/2023                 21          Ozone
# 3               3  01/04/2023                 25          Ozone
# 4               4  01/05/2023                 31          Ozone
# ...           ...         ...                ...            ...
# 10919       10919  12/27/2023                 54          PM2.5
# 10920       10920  12/28/2023                 41          PM2.5
# 10921       10921  12/29/2023                 41          Ozone
# 10922       10922  12/30/2023                 42          Ozone
# 10923       10923  12/31/2023                 60          PM2.5
#
#                           Site Name (of Overall AQI) Site ID (of Overall AQI)  \
# 0                                   Connecticut Hill              36-109-9991
# ...

# %%
# Replace '.' with None
df.replace(to_replace = '.', value = None, inplace = True)

# %%
# Remove Empty Cells
df.dropna(inplace = True)

# %%
df
# Out:
#        Unnamed: 0        Date  Overall AQI Value Main Pollutant  \
# 357           357  01/01/2023                 74          PM2.5
# 358           358  01/02/2023                 73          PM2.5
# 359           359  01/03/2023                 55          PM2.5
# 360           360  01/04/2023                 37          PM2.5
# 361           361  01/05/2023                 54          PM2.5
# ...           ...         ...                ...            ...
# 10909       10909  12/17/2023                 83          PM2.5
# 10912       10912  12/20/2023                 63          PM2.5
# 10915       10915  12/23/2023                 56          PM2.5
# 10918       10918  12/26/2023                 39          Ozone
# 10921       10921  12/29/2023                 41          Ozone
#
#                           Site Name (of Overall AQI) Site ID (of Overall AQI)  \
# 357                         REGIONAL OFFICE BUILDING              17-031-4007
# ...

# %%
# Remove ID-type columns
df.drop(['Unnamed: 0', 'Site ID (of Overall AQI)', 'Source (of Overall AQI)', 'Main Pollutant'], axis=1, inplace = True)

# %%
df
# Out:
#              Date  Overall AQI Value  \
# 357    01/01/2023                 74
# 358    01/02/2023                 73
# 359    01/03/2023                 55
# 360    01/04/2023                 37
# 361    01/05/2023                 54
# ...           ...                ...
# 10909  12/17/2023                 83
# 10912  12/20/2023                 63
# 10915  12/23/2023                 56
# 10918  12/26/2023                 39
# 10921  12/29/2023                 41
#
#                           Site Name (of Overall AQI) Ozone PM25 CO  PM10  \
# 357                         REGIONAL OFFICE BUILDING    15   74  7  26.0
# 358                                Hammond- 167th St    19   73  7  19.0
# 359                                Hammond- 167th St    19   55  6  31.0
# 360                                   VILLAGE GARAGE    21   37  3  17.0
# 361                      CHIWAUKEE PRAIRIE STATELINE    20   54  5  19.0
# ...

# %%
df['Date']
# Out:
# 357      01/01/2023
# 358      01/02/2023
# 359      01/03/2023
# 360      01/04/2023
# 361      01/05/2023
#             ...
# 10909    12/17/2023
# 10912    12/20/2023
# 10915    12/23/2023
# 10918    12/26/2023
# 10921    12/29/2023
# Name: Date, Length: 6494, dtype: object

# %%
# Keep only the year in Date
for date in df['Date']:
    df['Date'] = date[6:10]

# %%
df
# Out:
#        Date  Overall AQI Value                     Site Name (of Overall AQI)  \
# 357    2023                 74                       REGIONAL OFFICE BUILDING
# 358    2023                 73                              Hammond- 167th St
# 359    2023                 55                              Hammond- 167th St
# 360    2023                 37                                 VILLAGE GARAGE
# 361    2023                 54                    CHIWAUKEE PRAIRIE STATELINE
# ...     ...                ...                                            ...
# 10909  2023                 83  MARYSVILLE - 7TH AVE (Marysville Junior High)
# 10912  2023                 63   DARRINGTON - FIR ST (Darrington High School)
# 10915  2023                 56  MARYSVILLE - 7TH AVE (Marysville Junior High)
# 10918  2023                 39          MT RAINIER - JACKSON VISITIORS CENTER
# 10921  2023                 41          MT RAINIER - JACKSON VISITIORS CENTER
#
# ...

# %%
# Remove Ducplicate
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#        Date  Overall AQI Value                     Site Name (of Overall AQI)  \
# 357    2023                 74                       REGIONAL OFFICE BUILDING
# 358    2023                 73                              Hammond- 167th St
# 359    2023                 55                              Hammond- 167th St
# 360    2023                 37                                 VILLAGE GARAGE
# 361    2023                 54                    CHIWAUKEE PRAIRIE STATELINE
# ...     ...                ...                                            ...
# 10909  2023                 83  MARYSVILLE - 7TH AVE (Marysville Junior High)
# 10912  2023                 63   DARRINGTON - FIR ST (Darrington High School)
# 10915  2023                 56  MARYSVILLE - 7TH AVE (Marysville Junior High)
# 10918  2023                 39          MT RAINIER - JACKSON VISITIORS CENTER
# 10921  2023                 41          MT RAINIER - JACKSON VISITIORS CENTER
#
# ...

# %%
#Change type of some columns to float64
df[['Date', 'Overall AQI Value', 'Ozone', 'PM25', 'CO', 'PM10', 'NO2']] = df[['Date', 'Overall AQI Value', 'Ozone', 'PM25', 'CO', 'PM10', 'NO2']].astype('float')

# %%
#Change type of some columns to int64
df[['Date', 'Overall AQI Value', 'Ozone', 'PM25', 'CO', 'PM10', 'NO2']] = df[['Date', 'Overall AQI Value', 'Ozone', 'PM25', 'CO', 'PM10', 'NO2']].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6494 entries, 357 to 10921
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        6494 non-null   int64
#  1   Overall AQI Value           6494 non-null   int64
#  2   Site Name (of Overall AQI)  6494 non-null   object
#  3   Ozone                       6494 non-null   int64
#  4   PM25                        6494 non-null   int64
#  5   CO                          6494 non-null   int64
#  6   PM10                        6494 non-null   int64
#  7   NO2                         6494 non-null   int64
#  8   AQI category                6494 non-null   object
#  9   city                        6494 non-null   object
#  10  state                       6494 non-null   object
# dtypes: int64(7), object(4)
# memory usage: 608.8+ KB

# %%
df.to_csv('Processing_01.csv', index = False)
