# %%
import pandas as pd
import numpy as np

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
x_train = pd.read_csv('./data/x_train_dataset.csv')
y_train = pd.read_csv('./data/y_train_dataset.csv')

# %%
x_test = pd.read_csv('./data/x_test_dataset.csv')
y_test = pd.read_csv('./data/y_test_dataset.csv')

# %%
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.32025839,  0.02037077, -1.04893474, ..., -0.24494897,
#         -0.31431538, -0.2510722 ],
#        [-0.42698607, -0.60051224,  0.01193525, ...,  4.0824829 ,
#         -0.31431538, -0.2510722 ],
#        [-1.28080751, -0.96573754, -1.55630734, ..., -0.24494897,
#         -0.31431538, -0.2510722 ],
#        ...,
#        [ 1.35180861,  1.73692967,  0.61155742, ..., -0.24494897,
#         -0.31431538, -0.2510722 ],
#        [-0.42698607, -0.08919682, -0.54156213, ..., -0.24494897,
#         -0.31431538, -0.2510722 ],
#        [-0.39141017, -0.308332  ,  0.05806004, ..., -0.24494897,
#          3.18151783, -0.2510722 ]])

# %%
accu_list = []
for k in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train.values.ravel())
    y_pred = knn.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accu_list.append(accuracy)

# %%
accu_list
# Out:
# [0.7952270977675134,
#  0.7451886066204773,
#  0.7767513471901463,
#  0.7528868360277137,
#  0.7759815242494227,
#  0.7451886066204773,
#  0.7467282525019245,
#  0.7328714395688991,
#  0.7444187836797537,
#  0.7313317936874519,
#  0.7259430331023865,
#  0.7128560431100847,
#  0.7220939183987682,
#  0.7120862201693611,
#  0.7105465742879138,
#  0.7020785219399538,
#  0.7051578137028484,
#  0.6989992301770592,
#  0.6905311778290993,
#  0.6851424172440339,
#  0.6789838337182448,
#  0.6751347190146266,
#  0.6728252501924558,
#  0.665896843725943,
#  0.6674364896073903,
#  0.6674364896073903,
#  0.6635873749037722,
#  0.6689761354888376,
#  0.6682063125481139,
#  0.665896843725943,
#  0.6689761354888376,
#  0.6774441878367975,
#  0.6751347190146266,
#  0.6774441878367975,
#  0.6805234795996921,
#  0.6866820631254812,
#  0.6782140107775212,
#  0.6797536566589685,
#  0.6720554272517321,
#  0.6712856043110085,
#  0.6666666666666666,
#  0.6735950731331793,
#  0.6774441878367975,
# ...

# %%
import matplotlib.pyplot as plt

# %%
k_values = [i for i in range (1,100)]
sns.lineplot(x = k_values, y = accu_list, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("Accuracy Score")
# Out:
# Text(0, 0.5, 'Accuracy Score')

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#                                 precision    recall  f1-score   support
#
#                           Good       0.69      0.85      0.77       608
#                       Moderate       0.68      0.63      0.65       592
#                      Unhealthy       0.00      0.00      0.00        19
# Unhealthy for Sensitive Groups       0.00      0.00      0.00        76
#                 Very Unhealthy       0.00      0.00      0.00         4
#
#                       accuracy                           0.69      1299
#                      macro avg       0.27      0.30      0.28      1299
#                   weighted avg       0.63      0.69      0.66      1299
# C:\Users\hello\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
